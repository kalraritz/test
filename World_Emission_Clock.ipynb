# %%
pip install selenium

# %%
import numpy as np
import pandas as pd

# %%
from selenium import webdriver

driver=webdriver.Chrome()

driver.get("https://worldemissions.io/")

# %%
from selenium.webdriver.common.by import By
import time

## Sector
country_field = '//*[@id="SectorsHeader"]/div/div/input'
country = '//*[@id="SectorsHeader"]/div/div/div/div/p'
L1 = '//*[@id="sectors"]/article[2]/div[1]'
country_click = '//*[@id="SectorsHeader"]/div/div/ul/div/li/button/p'
country_click_congo = '//*[@id="SectorsHeader"]/div/div/ul/div/li[2]/button/p'
country_close = '//*[@id="SectorsHeader"]/div/div/div/img'

# countries = ["Indonesia", "Thailand", "Malaysia", "Viet Nam", "Philippines", "Singapore", "Cambodia", "Myanmar",
#             "Lao People's Democratic Republic", "Brunei Darussalam"]

countries = driver.find_element(By.XPATH, '//*[@id="SectorsHeader"]/div/div/ul').text.split('\n')[1:]

# Sub-sector
L2_data = '//*[@id="sectors"]/article[2]/aside/article[1]/div[2]/ul'
close = '//*[@id="sectors"]/article[2]/aside/article[1]/button'
L2_L1sector = '//*[@id="sectors"]/article[2]/aside/article[1]/div[1]/div[1]/h4'

L2_agri_click = '//*[@id="sectors"]/article[2]/div[2]/div[1]/button/span[2]'
L2_building_click ='//*[@id="sectors"]/article[2]/div[2]/div[2]/button/span[2]'
L2_energy_click = '//*[@id="sectors"]/article[2]/div[2]/div[3]/button/span[2]'
L2_industry_click = '//*[@id="sectors"]/article[2]/div[2]/div[4]/button/span[2]'
L2_transport_click = '//*[@id="sectors"]/article[2]/div[2]/div[5]/button/span[2]'

L2_clicks = [L2_agri_click, L2_building_click, L2_energy_click, L2_industry_click, L2_transport_click]

# Year slider
yslider = driver.find_element(By.XPATH,'//*[@id="root"]/main/section[6]/div/div[2]/div[3]/div/div/button')
y2022 = driver.find_element(By.XPATH, '//*[@id="root"]/main/section[6]/div/div[2]/div[3]/div/ul/li[3]')
y2030 = driver.find_element(By.XPATH, '//*[@id="root"]/main/section[6]/div/div[2]/div[3]/div/ul/li[11]')
year = driver.find_element(By.XPATH, '//*[@id="root"]/main/section[6]/div/div[2]/div[3]/div/div/span')

# %%
# setting up df
sectors =  ['Agriculture', 'Building', 'Energy', 'Industry', 'Transport']
L1_df = pd.DataFrame(columns = ['Year', 'Country', 'Sector', 'Emissions'])
L2_df = pd.DataFrame(columns = ['Year', 'Country', 'L1 Sector', 'L2 Sector','Emissions'])

#select years to scrape
years = [y2030]

for y in years:
    webdriver.ActionChains(driver).drag_and_drop(yslider, y).perform()
    current_year = year.text
    for i in countries:
        driver.find_element(By.XPATH, country_field).send_keys(i)
        time.sleep(2)
        ## exception for Congo since there are 2 Congos (but need to fix Guinea manually)
        if len(driver.find_element(By.XPATH, '//*[@id="SectorsHeader"]/div/div/ul').text.split('\n'))==1:
            driver.find_element(By.XPATH, country_click).click()
            time.sleep(3)
            aa = driver.find_element(By.XPATH, country).text
            aaa = driver.find_element(By.XPATH, L1).text
            aaaa = aaa.split('\n')
            print(aa)
            print(aaaa)
            temp_df = pd.DataFrame(
                {'Year': current_year, 'Country': aa,
                'Sector': sectors,
                'Emissions': aaaa}
            )
            L1_df = L1_df.append(temp_df, ignore_index=True)
        else:
            driver.find_element(By.XPATH, country_click_congo).click()
            time.sleep(1.5)
            aa = driver.find_element(By.XPATH, country).text
            aaa = driver.find_element(By.XPATH, L1).text
            aaaa = aaa.split('\n')
            print(aa)
            print(aaaa)
            temp_df = pd.DataFrame(
                {'Year': current_year, 'Country': aa,
                'Sector': sectors,
                'Emissions': aaaa}
            )
            L1_df = L1_df.append(temp_df, ignore_index=True)

        for j in L2_clicks:
            driver.find_element(By.XPATH, j).click()
            time.sleep(1.5)
            asd = driver.find_element(By.XPATH, L2_data).text.split('\n')
            L2_sectors = asd[::2]
            L2_emissions = asd[1::2]
            if L2_sectors != ['']:
                temp_df = pd.DataFrame(
                    {'Year': current_year, 'Country': driver.find_element(By.XPATH, country).text,
                    'L1 Sector': driver.find_element(By.XPATH, L2_L1sector).text,
                     'L2 Sector': L2_sectors,
                    'Emissions': L2_emissions})
                L2_df = L2_df.append(temp_df, ignore_index=True)
                driver.find_element(By.XPATH, close).click()
                time.sleep(1.5)
            else:
                driver.find_element(By.XPATH, close).click()
                time.sleep(2)
        driver.find_element(By.XPATH, country_close).click()

L1_df.to_csv(r"C:\Users\58706\Bain\Haran, Hari - 2023_Bayshore_Climate Strategy\6. Workstreams\1. GHG emission landscaping\World Emissions Clock\Output\World BAU\L1 - 2030.csv")
L2_df.to_csv(r"C:\Users\58706\Bain\Haran, Hari - 2023_Bayshore_Climate Strategy\6. Workstreams\1. GHG emission landscaping\World Emissions Clock\Output\World BAU\L2 - 2030.csv")
# Out:
# Aruba
# ['2.6 KT', '95.3 KT', '697.3 KT', '186.1 KT', '614.9 KT']
# Afghanistan
# ['17.7 MT', '374.3 KT', '4.9 MT', '13.4 MT', '3.0 MT']
# Angola
# ['65.1 MT', '5.6 MT', '25.4 MT', '17.4 MT', '11.8 MT']
# Albania
# ['19.4 KT', '429.1 KT', '253.3 KT', '3.9 MT', '2.4 MT']
# United Arab Emirates
# ['-7.0 MT', '2.4 MT', '153.7 MT', '155.7 MT', '44.6 MT']
# Argentina
# ['234.7 MT', '35.4 MT', '121.1 MT', '74.1 MT', '66.6 MT']
# Armenia
# ['1.7 MT', '2.8 MT', '2.7 MT', '1.5 MT', '3.6 MT']
# Australia
# ['62.1 MT', '16.2 MT', '236.7 MT', '99.4 MT', '106.6 MT']
# Austria
# ['5.5 MT', '7.2 MT', '16.5 MT', '26.3 MT', '26.1 MT']
# Azerbaijan
# ['8.9 MT', '10.5 MT', '23.0 MT', '11.2 MT', '11.4 MT']
# Burundi
# ['7.1 MT', '763.2 KT', '774.5 KT', '2.9 MT', '496.6 KT']
# Belgium
# ['8.2 MT', '19.1 MT', '25.5 MT', '36.9 MT', '24.4 MT']
# Benin
# ['18.4 MT', '1.5 MT', '2.3 MT', '8.1 MT', '11.3 MT']
# Burkina Faso
# ['52.6 MT', '2.5 MT', '3.3 MT', '10.7 MT', '4.4 MT']
# Bangladesh
# ['150.8 MT', '20.8 MT', '125.1 MT', '112.2 MT', '33.1 MT']
# Bulgaria
# ['-3.9 MT', '992.9 KT', '24.9 MT', '14.7 MT', '11.4 MT']
# Bahrain
# ['54.9 KT', '304.5 KT', '66.1 MT', '11.7 MT', '4.7 MT']
# Bahamas
# ['21.4 KT', '392.9 KT', '2.0 MT', '700.1 KT', '2.0 MT']
# Bosnia and Herzegovina
# ['274.6 KT', '882.0 KT', '17.5 MT', '7.7 MT', '5.3 MT']
# Belarus
# ['-19.3 MT', '3.7 MT', '27.4 MT', '29.5 MT', '12.7 MT']
# Belize
# ['5.6 MT', '84.2 KT', '474.5 KT', '424.7 KT', '367.9 KT']
# Bolivia - Plurinational State of
# ['119.5 MT', '1.9 MT', '14.6 MT', '7.7 MT', '15.6 MT']
# Brazil
# ['1.9 GT', '20.6 MT', '178.6 MT', '361.5 MT', '268.7 MT']
# Barbados
# ['41.7 KT', '135.5 KT', '1.2 MT', '441.2 KT', '824.5 KT']
# Brunei Darussalam
# ['482.0 KT', '88.2 KT', '10.5 MT', '965.9 KT', '1.6 MT']
# Bhutan
# ['-1.0 MT', '557.8 KT', '605.0 KT', '1.9 MT', '593.1 KT']
# Botswana
# ['43.1 MT', '227.9 KT', '6.7 MT', '1.9 MT', '3.8 MT']
# Central African Republic
# ['25.0 MT', '366.1 KT', '434.1 KT', '1.6 MT', '143.8 KT']
# Canada
# ['146.3 MT', '78.3 MT', '306.7 MT', '132.2 MT', '209.1 MT']
# Switzerland
# ['3.5 MT', '10.7 MT', '4.6 MT', '9.4 MT', '14.7 MT']
# Chile
# ['-47.9 MT', '7.2 MT', '55.3 MT', '47.3 MT', '34.1 MT']
# China
# ['574.6 MT', '586.7 MT', '7.9 GT', '5.0 GT', '1.3 GT']
# Côte d'Ivoire
# ['38.5 MT', '4.3 MT', '14.8 MT', '16.9 MT', '8.0 MT']
# Cameroon
# ['60.0 MT', '4.5 MT', '14.0 MT', '14.9 MT', '4.2 MT']
# Congo - the Democratic Republic of the
# ['978.6 MT', '8.3 MT', '20.8 MT', '30.6 MT', '2.5 MT']
# Congo
# ['21.9 MT', '862.7 KT', '24.4 MT', '2.8 MT', '1.8 MT']
# Colombia
# ['203.9 MT', '6.1 MT', '50.9 MT', '57.0 MT', '34.7 MT']
# Comoros
# ['315.1 KT', '82.4 KT', '199.2 KT', '389.5 KT', '209.2 KT']
# Cape Verde
# ['30.2 KT', '110.3 KT', '681.6 KT', '497.3 KT', '635.3 KT']
# Costa Rica
# ['-1.2 MT', '376.9 KT', '248.8 KT', '5.2 MT', '7.2 MT']
# Cuba
# ['6.3 MT', '798.8 KT', '14.3 MT', '9.9 MT', '1.7 MT']
# Cyprus
# ['1.8 MT', '596.6 KT', '3.6 MT', '2.9 MT', '2.3 MT']
# Czech Republic
# ['25.8 MT', '9.3 MT', '48.6 MT', '20.4 MT', '20.2 MT']
# Germany
# ['31.7 MT', '101.4 MT', '234.7 MT', '163.4 MT', '149.7 MT']
# Djibouti
# ['847.2 KT', '94.7 KT', '267.0 KT', '1.0 MT', '458.2 KT']
# Denmark
# ['14.2 MT', '2.0 MT', '6.1 MT', '6.1 MT', '12.8 MT']
# Dominican Republic
# ['8.7 MT', '2.1 MT', '14.3 MT', '18.5 MT', '8.0 MT']
# Algeria
# ['11.2 MT', '31.5 MT', '139.1 MT', '61.8 MT', '57.8 MT']
# Ecuador
# ['46.6 MT', '5.0 MT', '32.7 MT', '12.7 MT', '25.9 MT']
# Egypt
# ['38.1 MT', '24.0 MT', '262.3 MT', '148.9 MT', '97.0 MT']
# Eritrea
# ['5.1 MT', '270.6 KT', '935.4 KT', '1.4 MT', '331.8 KT']
# Spain
# ['29.3 MT', '25.7 MT', '82.6 MT', '77.2 MT', '94.1 MT']
# Estonia
# ['3.8 MT', '566.9 KT', '12.9 MT', '3.6 MT', '3.3 MT']
# Ethiopia
# ['176.0 MT', '19.9 MT', '6.3 MT', '39.6 MT', '14.9 MT']
# Finland
# ['-318.7 KT', '1.4 MT', '25.4 MT', '19.6 MT', '10.6 MT']
# Fiji
# ['-2.4 MT', '50.5 KT', '425.7 KT', '1.1 MT', '1.1 MT']
# France
# ['59.6 MT', '54.2 MT', '48.2 MT', '97.4 MT', '126.2 MT']
# Gabon
# ['14.7 MT', '917.2 KT', '12.7 MT', '3.8 MT', '363.1 KT']
# United Kingdom
# ['121.9 MT', '79.3 MT', '89.9 MT', '58.6 MT', '104.4 MT']
# Georgia
# ['2.1 MT', '3.0 MT', '1.7 MT', '9.5 MT', '7.9 MT']
# Ghana
# ['-14.9 MT', '1.7 MT', '50.3 MT', '15.1 MT', '12.8 MT']
# Guinea-Bissau
# ['13.8 MT', '477.9 KT', '257.1 KT', '690.8 KT', '158.7 KT']
# Gambia
# ['7.5 MT', '155.5 KT', '447.7 KT', '801.6 KT', '501.8 KT']
# Guinea-Bissau
# ['13.8 MT', '477.9 KT', '257.1 KT', '690.8 KT', '158.7 KT']
# Equatorial Guinea
# ['7.6 MT', '175.0 KT', '4.5 MT', '3.8 MT', '333.5 KT']
# Greece
# ['1.9 MT', '4.2 MT', '29.7 MT', '22.3 MT', '15.8 MT']
# Guatemala
# ['18.7 MT', '5.0 MT', '9.8 MT', '17.0 MT', '14.4 MT']
# Guyana
# ['19.3 MT', '239.0 KT', '4.9 MT', '4.5 MT', '6.4 MT']
# Hong Kong
# ['30.8 KT', '1.5 MT', '26.0 MT', '7.3 MT', '6.0 MT']
# Honduras
# ['15.3 MT', '1.0 MT', '4.7 MT', '7.0 MT', '6.1 MT']
# Croatia
# ['-643.2 KT', '2.4 MT', '4.5 MT', '10.6 MT', '9.0 MT']
# Haiti
# ['4.9 MT', '1.2 MT', '5.7 MT', '3.4 MT', '1.8 MT']
# Hungary
# ['5.4 MT', '10.3 MT', '13.6 MT', '18.8 MT', '20.6 MT']
# Indonesia
# ['904.9 MT', '18.2 MT', '771.1 MT', '310.5 MT', '214.4 MT']
# India
# ['668.1 MT', '172.7 MT', '2.1 GT', '1.5 GT', '532.0 MT']
# Ireland
# ['30.2 MT', '8.1 MT', '12.7 MT', '7.5 MT', '15.5 MT']
# Iran - Islamic Republic of
# ['25.5 MT', '171.0 MT', '559.7 MT', '273.7 MT', '192.5 MT']
# Iraq
# ['8.7 MT', '6.6 MT', '300.2 MT', '52.8 MT', '31.8 MT']
# Iceland
# ['6.2 MT', '3.5 KT', '5.8 KT', '2.8 MT', '1.2 MT']
# Israel
# ['3.6 MT', '352.0 KT', '35.5 MT', '32.2 MT', '20.2 MT']
# Italy
# ['13.6 MT', '60.6 MT', '90.4 MT', '74.8 MT', '101.8 MT']
# Jamaica
# ['5.3 MT', '533.0 KT', '2.3 MT', '3.6 MT', '2.8 MT']
# Jordan
# ['-148.1 KT', '2.0 MT', '12.0 MT', '16.3 MT', '11.6 MT']
# Japan
# ['34.0 MT', '83.1 MT', '606.9 MT', '271.9 MT', '164.4 MT']
# Kazakhstan
# ['114.1 MT', '45.5 MT', '127.6 MT', '38.3 MT', '18.4 MT']
# Kenya
# ['111.3 MT', '6.0 MT', '15.7 MT', '32.2 MT', '21.4 MT']
# Kyrgyzstan
# ['5.7 MT', '6.3 MT', '2.6 MT', '6.0 MT', '3.1 MT']
# Cambodia
# ['52.7 MT', '1.4 MT', '10.7 MT', '9.3 MT', '10.6 MT']
# Korea - Republic of
# ['-17.3 MT', '49.0 MT', '419.8 MT', '179.4 MT', '110.2 MT']
# Kuwait
# ['521.9 KT', '1.1 MT', '101.3 MT', '48.3 MT', '12.0 MT']
# Lao People's Democratic Republic
# ['21.0 MT', '455.2 KT', '16.9 MT', '6.2 MT', '3.1 MT']
# Lebanon
# ['692.0 KT', '408.4 KT', '18.0 MT', '11.4 MT', '7.6 MT']
# Liberia
# ['13.7 MT', '1.9 MT', '1.3 MT', '2.0 MT', '842.6 KT']
# Libya
# ['3.0 MT', '2.0 MT', '73.0 MT', '19.0 MT', '25.6 MT']
# Saint Lucia
# ['-112.7 KT', '63.5 KT', '386.4 KT', '200.3 KT', '327.6 KT']
# Sri Lanka
# ['16.3 MT', '1.8 MT', '10.1 MT', '7.9 MT', '9.3 MT']
# Lesotho
# ['1.4 MT', '353.7 KT', '444.7 KT', '629.7 KT', '463.0 KT']
# Lithuania
# ['-2.1 MT', '1.3 MT', '2.0 MT', '9.5 MT', '7.4 MT']
# Luxembourg
# ['245.5 KT', '1.4 MT', '250.8 KT', '1.0 MT', '4.6 MT']
# Latvia
# ['1.7 MT', '868.3 KT', '1.8 MT', '3.2 MT', '3.9 MT']
# Macao
# ['3.4 KT', '58.6 KT', '796.8 KT', '707.0 KT', '1.2 MT']
# Morocco
# ['13.9 MT', '11.1 MT', '36.8 MT', '43.1 MT', '32.2 MT']
# Moldova - Republic of
# ['2.0 MT', '1.6 MT', '3.2 MT', '4.0 MT', '3.4 MT']
# Madagascar
# ['35.3 MT', '3.1 MT', '4.9 MT', '11.7 MT', '1.9 MT']
# Maldives
# ['195.0 tons', '144.2 KT', '1.1 MT', '957.9 KT', '2.1 MT']
# Mexico
# ['129.6 MT', '19.5 MT', '198.8 MT', '315.1 MT', '181.4 MT']
# Republic of North Macedonia
# ['19.8 MT', '180.8 KT', '2.6 MT', '4.1 MT', '3.2 MT']
# Somalia
# ['52.8 MT', '3.1 MT', '3.2 MT', '7.5 MT', '439.8 KT']
# Malta
# ['47.9 KT', '134.5 KT', '337.0 KT', '543.8 KT', '849.6 KT']
# Myanmar
# ['257.4 MT', '5.7 MT', '26.3 MT', '25.7 MT', '15.0 MT']
# Montenegro
# ['433.1 KT', '128.2 KT', '1.2 MT', '485.2 KT', '1.6 MT']
# Mongolia
# ['36.5 MT', '2.5 MT', '55.5 MT', '4.0 MT', '3.7 MT']
# Mozambique
# ['62.1 MT', '2.5 MT', '25.6 MT', '13.7 MT', '7.4 MT']
# Mauritania
# ['20.4 MT', '636.9 KT', '1.8 MT', '4.1 MT', '2.8 MT']
# Mauritius
# ['84.9 KT', '214.3 KT', '4.3 MT', '3.3 MT', '1.4 MT']
# Malawi
# ['18.1 MT', '1.1 MT', '1.8 MT', '5.9 MT', '671.8 KT']
# Malaysia
# ['112.8 MT', '3.4 MT', '265.9 MT', '111.1 MT', '83.0 MT']
# Namibia
# ['17.3 MT', '88.3 KT', '1.3 MT', '2.0 MT', '3.9 MT']
# Nigeria
# ['139.1 MT', '56.5 MT', '117.0 MT', '109.1 MT', '77.7 MT']
# Nigeria
# ['139.1 MT', '56.5 MT', '117.0 MT', '109.1 MT', '77.7 MT']
# Nicaragua
# ['33.4 MT', '1.3 MT', '1.4 MT', '3.6 MT', '2.6 MT']
# Netherlands
# ['33.2 MT', '19.5 MT', '67.4 MT', '59.9 MT', '29.1 MT']
# Norway
# ['-2.2 MT', '964.6 KT', '38.8 MT', '16.3 MT', '13.0 MT']
# Nepal
# ['53.5 MT', '6.6 MT', '440.1 KT', '15.2 MT', '9.5 MT']
# New Zealand
# ['31.2 MT', '1.7 MT', '5.5 MT', '17.5 MT', '16.3 MT']
# Romania
# ['-15.2 MT', '11.7 MT', '24.8 MT', '30.8 MT', '24.5 MT']
# Pakistan
# ['318.9 MT', '45.7 MT', '94.4 MT', '194.3 MT', '75.9 MT']
# Panama
# ['8.6 MT', '762.1 KT', '4.9 MT', '7.4 MT', '6.2 MT']
# Peru
# ['233.7 MT', '3.9 MT', '31.0 MT', '26.7 MT', '30.2 MT']
# Philippines
# ['74.2 MT', '18.6 MT', '146.1 MT', '75.4 MT', '41.2 MT']
# Papua New Guinea
# ['79.3 MT', '574.1 KT', '7.6 MT', '2.7 MT', '4.2 MT']
# Poland
# ['36.7 MT', '35.4 MT', '154.9 MT', '59.5 MT', '89.2 MT']
# Puerto Rico
# ['728.6 KT', '226.1 KT', '28.2 KT', '2.6 MT', '21.3 KT']
# Portugal
# ['2.1 MT', '3.1 MT', '16.0 MT', '18.7 MT', '17.0 MT']
# Paraguay
# ['89.4 MT', '699.9 KT', '2.0 MT', '4.1 MT', '11.1 MT']
# Qatar
# ['756.0 KT', '490.7 KT', '137.2 MT', '50.7 MT', '11.9 MT']
# Romania
# ['-15.2 MT', '11.7 MT', '24.8 MT', '30.8 MT', '24.5 MT']
# Russian Federation
# ['31.1 MT', '218.3 MT', '1.1 GT', '480.2 MT', '258.2 MT']
# Rwanda
# ['7.1 MT', '728.7 KT', '450.8 KT', '3.4 MT', '656.3 KT']
# Saudi Arabia
# ['-6.6 MT', '9.8 MT', '535.6 MT', '421.4 MT', '179.0 MT']
# Sudan
# ['124.4 MT', '3.3 MT', '16.4 MT', '20.6 MT', '14.3 MT']
# Senegal
# ['22.5 MT', '1.2 MT', '7.6 MT', '13.4 MT', '4.6 MT']
# Singapore
# ['46.4 KT', '1.1 MT', '29.9 MT', '50.1 MT', '8.0 MT']
# Solomon Islands
# ['45.5 MT', '16.8 KT', '71.0 KT', '237.8 KT', '260.1 KT']
# Sierra Leone
# ['7.2 MT', '998.3 KT', '1.2 MT', '2.0 MT', '514.5 KT']
# El Salvador
# ['4.9 MT', '807.3 KT', '2.5 MT', '5.1 MT', '4.0 MT']
# Somalia
# ['52.8 MT', '3.1 MT', '3.2 MT', '7.5 MT', '439.8 KT']
# Serbia
# ['4.1 MT', '2.9 MT', '34.4 MT', '10.0 MT', '9.7 MT']
# Sao Tome and Principe
# ['233.1 KT', '22.5 KT', '61.7 KT', '94.9 KT', '103.4 KT']
# Suriname
# ['9.8 MT', '115.8 KT', '1.2 MT', '282.1 KT', '1.6 MT']
# Slovakia
# ['-4.6 MT', '2.9 MT', '6.0 MT', '22.6 MT', '8.4 MT']
# Slovenia
# ['-724.0 KT', '597.1 KT', '6.0 MT', '5.8 MT', '7.0 MT']
# Sweden
# ['-10.4 MT', '941.9 KT', '9.9 MT', '24.9 MT', '14.4 MT']
# Eswatini
# ['2.0 MT', '273.0 KT', '404.3 KT', '1.2 MT', '569.6 KT']
# Chad
# ['115.7 MT', '1.5 MT', '3.1 MT', '5.6 MT', '1.1 MT']
# Togo
# ['4.7 MT', '885.5 KT', '3.5 MT', '4.5 MT', '1.9 MT']
# Thailand
# ['90.7 MT', '7.6 MT', '139.1 MT', '188.0 MT', '87.7 MT']
# Tajikistan
# ['12.4 MT', '1.6 MT', '5.1 MT', '7.7 MT', '2.0 MT']
# Turkmenistan
# ['17.6 MT', '19.4 MT', '76.0 MT', '10.6 MT', '11.3 MT']
# Timor-Leste
# ['9.8 MT', '23.8 KT', '1.2 MT', '404.4 KT', '329.9 KT']
# Tonga
# ['-1.7 MT', '3.8 KT', '43.3 KT', '58.5 KT', '124.9 KT']
# Trinidad and Tobago
# ['753.9 KT', '332.2 KT', '24.7 MT', '28.1 MT', '2.6 MT']
# Tunisia
# ['-827.2 KT', '3.7 MT', '15.8 MT', '16.1 MT', '10.1 MT']
# Turkey
# ['38.8 MT', '82.2 MT', '245.9 MT', '280.9 MT', '122.3 MT']
# Taiwan
# ['-13.1 MT', '6.9 MT', '170.5 MT', '76.4 MT', '33.0 MT']
# Tanzania - United Republic of
# ['129.8 MT', '5.9 MT', '18.9 MT', '23.2 MT', '7.5 MT']
# Uganda
# ['58.5 MT', '7.1 MT', '5.4 MT', '15.4 MT', '4.5 MT']
# Ukraine
# ['14.9 MT', '10.5 MT', '59.9 MT', '32.1 MT', '17.1 MT']
# Uruguay
# ['29.0 MT', '561.1 KT', '2.0 MT', '9.8 MT', '4.6 MT']
# United States
# ['259.0 MT', '507.6 MT', '2.0 GT', '914.9 MT', '1.7 GT']
# Uzbekistan
# ['66.6 MT', '35.7 MT', '95.5 MT', '39.6 MT', '26.0 MT']
# Saint Vincent and the Grenadines
# ['8.0 KT', '17.9 KT', '170.7 KT', '80.3 KT', '116.3 KT']
# Venezuela - Bolivarian Republic of
# ['140.1 MT', '3.0 MT', '99.3 MT', '38.5 MT', '28.9 MT']
# Viet Nam
# ['85.9 MT', '7.6 MT', '249.6 MT', '268.6 MT', '53.6 MT']
# Vanuatu
# ['489.4 KT', '14.6 KT', '76.3 KT', '178.5 KT', '149.9 KT']
# Samoa
# ['395.1 KT', '16.7 KT', '115.8 KT', '104.8 KT', '273.7 KT']
# Yemen
# ['5.3 MT', '2.5 MT', '10.9 MT', '23.5 MT', '4.9 MT']
# South Africa
# ['50.5 MT', '40.2 MT', '320.5 MT', '103.5 MT', '59.3 MT']
# Zambia
# ['50.3 MT', '2.2 MT', '8.0 MT', '7.1 MT', '2.9 MT']
# Zimbabwe
# ['102.0 MT', '3.0 MT', '8.3 MT', '6.6 MT', '3.7 MT']

# %%
# manual corrections
L1_df_manual = pd.DataFrame(columns = ['Year', 'Country', 'Sector', 'Emissions'])
L2_df_manual = pd.DataFrame(columns = ['Year', 'Country', 'L1 Sector', 'L2 Sector','Emissions'])
manual_countries = ["Guinea", "Niger", "Oman"]

#select years to scrape
years = [y2030]

for y in years:
    webdriver.ActionChains(driver).drag_and_drop(yslider, y).perform()
    current_year = year.text
    for i in manual_countries:
        driver.find_element(By.XPATH, country_field).send_keys(i)
        time.sleep(2)
        driver.find_element(By.XPATH, country_click).click()
        time.sleep(3)
        aa = driver.find_element(By.XPATH, country).text
        aaa = driver.find_element(By.XPATH, L1).text
        aaaa = aaa.split('\n')
        print(aa)
        print(aaaa)
        temp_df = pd.DataFrame(
                    {'Year': current_year, 'Country': aa,
                    'Sector': sectors,
                    'Emissions': aaaa}
                )
        L1_df_manual = L1_df_manual.append(temp_df, ignore_index=True)

        for j in L2_clicks:
            driver.find_element(By.XPATH, j).click()
            time.sleep(1.5)
            asd = driver.find_element(By.XPATH, L2_data).text.split('\n')
            L2_sectors = asd[::2]
            L2_emissions = asd[1::2]
            if L2_sectors != ['']:
                temp_df = pd.DataFrame(
                    {'Year': current_year, 'Country': driver.find_element(By.XPATH, country).text,
                    'L1 Sector': driver.find_element(By.XPATH, L2_L1sector).text,
                     'L2 Sector': L2_sectors,
                    'Emissions': L2_emissions})
                L2_df_manual = L2_df_manual.append(temp_df, ignore_index=True)
                driver.find_element(By.XPATH, close).click()
                time.sleep(1.5)
            else:
                driver.find_element(By.XPATH, close).click()
                time.sleep(2)
        driver.find_element(By.XPATH, country_close).click()

L1_df_manual.to_csv(r"C:\Users\58706\Bain\Haran, Hari - 2023_Bayshore_Climate Strategy\6. Workstreams\1. GHG emission landscaping\World Emissions Clock\Output\World BAU\L1 - 2030_manual.csv")
L2_df_manual.to_csv(r"C:\Users\58706\Bain\Haran, Hari - 2023_Bayshore_Climate Strategy\6. Workstreams\1. GHG emission landscaping\World Emissions Clock\Output\World BAU\L2 - 2030_manual.csv")
# Out:
# Guinea
# ['39.6 MT', '2.3 MT', '2.6 MT', '8.0 MT', '1.9 MT']
# Niger
# ['55.9 MT', '2.2 MT', '2.3 MT', '7.6 MT', '2.2 MT']
# Oman
# ['2.3 MT', '22.2 MT', '83.7 MT', '45.9 MT', '17.5 MT']
